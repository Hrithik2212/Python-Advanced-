# %% [markdown]
# # Matplotlib

# %%
# imports
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1. Write python code to the following line chat.

# %%
x = np.linspace(1,5,5)
y = 2*((x+2)**2)+4
y2 = 2*(x**2)+4
fig = plt.figure()
plt.grid()
plt.xlim(-1,10)
plt.ylim(0,70)
plt.plot(y2)
plt.plot(y)
plt.title("City RainFall Accident Forecast")
plt.xlabel("Day of a Month")
plt.ylabel("Count")
def yp(x):
    return 2*((x+2)**2)+4
def y2p(x):
    return 2*(x**2)+4
for i in range(0,6):
    plt.annotate(f"Day{i+1} RF",xy=(i,yp(i)),xytext=(i,yp(i)+12),horizontalalignment='left',verticalalignment='top')
    plt.annotate(f"Day{i+1} Acc",xy=(i,y2p(i)),xytext=(i,y2p(i)+12),horizontalalignment='left',verticalalignment='top')

# %% [markdown]
# ### 2. Write python code to the following line chat.

# %%
plt.plot(np.random.randn(25).cumsum(),label='WARP')
plt.plot(np.random.randn(25).cumsum(),label='RLL-CNN')
plt.plot(np.random.randn(25).cumsum(),label='CNN+LSTM+RMLC')
plt.legend()
plt.xlabel("Label Corruption")
plt.ylabel("Classification Accuracy")
# Out:
# Text(0, 0.5, 'Classification Accuracy')

# %% [markdown]
# ### 3.Draw a line chart for the following data and add title, xticks, yticks, label to xticks,label to yticks, x-axis label, y-axis label and legends.

# %%
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)
Time = ['9 am','10 am','11 am','12 noon','1 pm','2 pm','3 pm']
Temperature = [35,36,39,38,36.5,36.5,37]
T = []
for i in range(345,395,5):
    a =str(i/10)+' C'
    T.append(a)
ax.plot(Temperature,'o-',label='T graph',)
ax.set_xticklabels(Time);
ax.set_yticklabels(T);
ax.set_xlabel('Time')
ax.set_ylabel('Tmperature')
ax.set_title('Time vs Temperature')
ax.legend()
# Out:
# C:\Users\HRITHI~1\AppData\Local\Temp/ipykernel_3880/909389149.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(Time);
# C:\Users\HRITHI~1\AppData\Local\Temp/ipykernel_3880/909389149.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(T);

# %% [markdown]
# ### 4. Consider the pandas data frame df = pd.DataFrame(np.random.rand(4, 4)) construct a bar chart data in df.

# %%
df = pd.DataFrame(np.random.rand(4, 4))
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
A
